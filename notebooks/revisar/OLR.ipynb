# %%
import os
import glob
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import dask.array as da

# %%
OLR=xr.open_dataset(r"C:\Users\paola\Tesis\01_Data\OLR\OLR-Daily_v02r00_s19790101_e20231231.nc")

# %%
OLR
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:      (time: 16436, lat: 180, lon: 360, bnds: 2)
# Coordinates:
#   * lon          (lon) float32 1kB 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#   * lat          (lat) float32 720B -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * time         (time) datetime64[ns] 131kB 1979-01-01T12:00:00 ... 2023-12-...
# Dimensions without coordinates: bnds
# Data variables:
#     olr          (time, lat, lon) float32 4GB ...
#     lon_bounds   (time, lon, bnds) float32 47MB ...
#     lat_bounds   (time, lat, bnds) float32 24MB ...
#     time_bounds  (time, bnds) datetime64[ns] 263kB ...
# Attributes: (12/46)
#     conventions:                CF-1.6, ACDD-1.3
#     title:                      OLR-Daily CDR Product Ver02Rev00
#     source:                     NOAA Archive of HIRS L1B data from TIROS-N Se...
#     reference:                  doi:10.1175/2007JTECHA989.1  doi:10.1175/1520...
# ...

# %%
OLR.olr.mean(dim="time").plot()
